# %% [markdown]
# Object tracking usinmg yolov9 and byte tracker

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 34.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Detect

# %%
from ultralytics import YOLO

#use a YOLOv9 model from pretrained weight
model = YOLO('yolov9c.pt')

#run inference
results = model('1.mp4',save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/596) /content/1.mp4: 384x640 15 persons, 3 cars, 4 traffic lights, 4 umbrellas, 1 handbag, 1 tv, 56.8ms
# video 1/1 (frame 2/596) /content/1.mp4: 384x640 14 persons, 3 cars, 4 traffic lights, 4 umbrellas, 3 handbags, 1 tv, 33.8ms
# video 1/1 (frame 3/596) /content/1.mp4: 384x640 13 persons, 3 cars, 4 traffic lights, 6 umbrellas, 1 handbag, 1 tv, 31.7ms
# ...

# %% [markdown]
# Tracker

# %%
from ultralytics import YOLO

model = YOLO('yolov9c.pt')

results = model.track('1.mp4',save=True)
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 54.0 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 2.4s, installed 1 package: ['lap>=0.5.12']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %% [markdown]
# Train on Custom Dataset
# Data: https://universe.roboflow.com/mahmoud-9wyf6/fire-n-smoke-detection/dataset/1/download/yolov8

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uwcEFW4wjiuJayCklGmS")
project = rf.workspace("mahmoud-9wyf6").project("fire-n-smoke-detection")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FIRE-n-SMOKE-DETECTION-1 in yolov9:: 100%|██████████| 1786/1786 [00:00<00:00, 9060.93it/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov9c.pt')

results = model.train(data='/content/FIRE-n-SMOKE-DETECTION-1/data.yaml',epochs = 5, imgsz = 640)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

#load pretrained model

model = YOLO('/content/runs/detect/train/weights/best.pt')

model.predict('fire.mp4',save=True,imgsz=640,conf=0.5)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/694) /content/fire.mp4: 352x640 (no detections), 57.0ms
# video 1/1 (frame 2/694) /content/fire.mp4: 352x640 (no detections), 30.9ms
# video 1/1 (frame 3/694) /content/fire.mp4: 352x640 (no detections), 30.9ms
# video 1/1 (frame 4/694) /content/fire.mp4: 352x640 (no detections), 37.8ms
# video 1/1 (frame 5/694) /content/fire.mp4: 352x640 (no detections), 30.9ms
# ...
